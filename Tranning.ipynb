# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import os
import datetime
from selenium.webdriver.support.ui import Select
from urllib.parse import quote
import json
import requests
from bs4 import BeautifulSoup
import re
import urllib.parse
from IPython.display import clear_output
import threading
from functools import partial
skip = 0.3
driver_path = "chromedriver.exe" 
file_path = "data.json"
link_path = "link.json"
error_path = "error.json"
intent_path = "intent.json"
after_path = "after.json"
tophit_path = "tophit.json"

# %%
# đọc
# with open(file_path, 'r') as json_file:
#     datajs = json.load(json_file)
with open(link_path, 'r') as json_file:
    linkjs = json.load(json_file)
with open(error_path, 'r') as json_file:
    errorjs = json.load(json_file)
with open(intent_path, 'r') as json_file:
    intentjs = json.load(json_file)

# %%
datajs ={}

# %%
# GHI 
with open(file_path, 'w') as json_file:
    json.dump(datajs, json_file)
with open(link_path, 'w') as json_file:
    json.dump(linkjs, json_file)    
with open(error_path, 'w') as json_file:
    json.dump(errorjs, json_file)

# %%
 # Thay đổi thành đường dẫn tới ChromeDriver trên máy của bạn
driver = webdriver.Chrome()
driver1 = webdriver.Chrome()
driver2 = webdriver.Chrome()
url = f"https://baseline.apple.com/"
url1 = f"https://chrome.google.com/webstore/detail/nordvpn-vpn-proxy-for-pri/fjoaledfpmneenckfbpdfhkmimnjocfa"
url2 = f"https://chrome.google.com/webstore/detail/proxy-helper/mnloefcpaepkpmhaoipjkpikbnkmbnic"
#mathias.d.kristensen@gmail.com
#Mdkmdkdk99
#45.80.229.85
#:8000:BKott4:5zt7Ck
#fernandesalomon387@gmail.com		AppleID@160
#https://chrome.google.com/webstore/detail/nlipoenfbbikpbjkfpfillcgkoblgpmj
#107.186.189.126:
#64694:eJyLCJqM:GrSHLfUf
#nive6845@gmail.com                8it3$0fH0n3y

# %%
driver1 = webdriver.Chrome()
driver1.get('https://open.spotify.com/')
while True:
    try:
        Login= driver1.find_element(By.XPATH,"//button[@data-testid='login-button']")
        Login.click()
        print('dfasdf')
        break
    except:
        time.sleep(skip)
        print('llklkl')
time.sleep(5)  
email = driver1.find_element(By.XPATH,"//input[@id='login-username']")
email.send_keys('sunghajung00001@gmail.com')
password = driver1.find_element(By.XPATH,"//input[@id='login-password']")
password.send_keys('Lkcntt2mtak55')
time.sleep(skip)  
Login= driver1.find_element(By.XPATH,"//button[@id='login-button']")
Login.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[6], line 2
#       1 driver1 = webdriver.Chrome()
# ----> 2 driver1.get('https://open.spotify.com/')
#       3 while True:
#       4     try:
#
# File D:\PycharmProject\Media\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:353, in WebDriver.get(self, url)
#     351 def get(self, url: str) -> None:
#     352     """Loads a web page in the current browser session."""
# --> 353     self.execute(Command.GET, {"url": url})
#
# File D:\PycharmProject\Media\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:344, in WebDriver.execute(self, driver_command, params)
#     342 response = self.command_executor.execute(driver_command, params)
#     343 if response:
# --> 344     self.error_handler.check_response(response)
#     345     response["value"] = self._unwrap_value(response.get("value", None))
# ...

# %%
driver.get(url2)
driver2.get('https://music.apple.com/us/browse')
driver1.get('https://open.spotify.com/')
while True:
    try:
        Login= driver1.find_element(By.XPATH,"//button[@data-testid='login-button']")
        Login.click()
        print('dfasdf')
        break
    except:
        time.sleep(skip)
        print('llklkl')
time.sleep(5)  
email = driver1.find_element(By.XPATH,"//input[@id='login-username']")
email.send_keys('sunghajung00001@gmail.com')
password = driver1.find_element(By.XPATH,"//input[@id='login-password']")
password.send_keys('Lkcntt2mtak55')
time.sleep(skip)  
Login= driver1.find_element(By.XPATH,"//button[@id='login-button']")
Login.click()
# Out:
# dfasdf

# %%
def contains_digit(input_string):
    for char in input_string:
        if char.isdigit():
            return True
    return False
def translate(text_to_translate):
    
# Tìm phần nhập văn bản nguồn và đích
    source_text_box = driver4.find_element(By.XPATH,"//textarea[@aria-label='Source text']")
    source_text_box.clear()
    source_text_box.send_keys(text_to_translate)
    
    # Đợi một lát để Google Translate tự động dịch
    time.sleep(10)
    result_text_box = driver4.find_element(By.XPATH,"//div[@class='lRu31']")
    # Lấy kết quả dịch
    translated_text = result_text_box.text
    
    # In ra kết quả
    return translated_text
def check_startswith(x, y):
    if y.startswith(x) and x != y:
        return True
    return False
def check_output(input_str, output_str):
    # Tìm vị trí của input_str trong output_str
    index = output_str.find(input_str)
    
    # Kiểm tra xem input_str có trong output_str hay không
    if index != -1:
        # Nếu input_str nằm trong ngoặc () trong output_str, print 0
        if '(' in output_str[:index] and ')' in output_str[index + len(input_str):]:
            return True
        else:
            return False
    else:
        return False
    
#Đánh giá rank
def rank(relevant):
    #How relevant is this result?
    rank = driver.find_element(By.XPATH,"//select[@id='task_judgments_attributes_0_answer_id']")
    combo = Select(rank)
    combo.select_by_value(relevant) 
def write_comment(comment):
    box = driver.find_element(By.XPATH,"//textarea[@id='task_comment']")
    box.send_keys(comment) 

def delete_comment():
    box = driver.find_element(By.XPATH,"//textarea[@id='task_comment']")
    box.clear()
    
def single(link,artist):
    print('single',link,artist)
    album = link
    driver2.get(album)
    time.sleep(4)
    print('Đã mở album. Ktra xem có phải là single album không')
    print(driver2.find_element(By.XPATH,"//h1").text)
    if "can’t be found" in driver2.find_element(By.XPATH,"//h1").text or '찾으시는 페이지를 찾을 수 없습니' in driver2.find_element(By.XPATH,"//h1").text:
        return None
    else:
        a = driver2.find_elements(By.XPATH,"//div[@class='songs-list-row__song-wrapper svelte-4hjdmk']")
        print(len(a))
        if len(a) == 1:
            song = a[0].text+ ' ' + artist
            print('song in album :',song)
            return song
        else: 
            return None


def info():
    
        
    name = None
    art  = None
    tws = time.time()
    twr = 0
    while (not name or not art) and twr < 120:
        try:
            name = driver1.find_element(By.XPATH, "//h1").text
            art = driver1.find_element(By.XPATH,"//section[@data-testid='track-page']//div/span/a").text
        except:
            time.sleep(skip)
            twr = time.time() - tws
        
    try:
        x = driver1.find_element(By.XPATH, "//span[@data-testid='playcount']")
        y = x.text
        x_text = y.replace(',', '')  # Loại bỏ dấu phẩy từ chuỗi
        view_count = int(x_text)
    except Exception as e:
        view_count = 0
        y = None
    if view_count >= 4000000:
        popu = "popular"
    else:
        popu = "unpopular"
    if y:
        op_song = f"song {name} by {art} (+{y} streams in Spotify) "
    else:
        op_song = f"song {name} by {art}"
    return popu, op_song
def findsong1(key,result_variable):
    
    input_string = key.replace(' by ',' ')
    encoded_string = urllib.parse.quote(input_string)
    spotify_link = f"https://open.spotify.com/search/{encoded_string}/tracks"
    driver1.get(spotify_link)
    time.sleep(1)
    upstream = driver1.find_element(By.XPATH,"//body").text
    while 'upstream' in upstream.lower():
        print(upstream.lower())
        driver1.get(spotify_link)
        time.sleep(2)
        upstream = driver1.find_element(By.XPATH,"//body").text
        
    try: 
        errormes = driver1.find_element(By.XPATH,"//h1").text
        print(errormes.lower())
    except:
        errormes = 'ddd'
    print(errormes.lower(), ' <> ')
    if 'found for' in errormes.lower() or 'not found' in errormes.lower() or 'No Podcasts & Shows' in errormes :
        popu = 'unpopular'
        song = result
    else:
        time.sleep(skip)
        c = None
        tws = time.time()
        twr = 0
        while not c and twr < 120:
            c = driver1.find_elements(By.XPATH,"//div[@class='iCQtmPqY0QvkumAOuCjr']")
            time.sleep(skip)
            twr = time.time() - tws
            
        print('c:', len(c))
        i = 0
        for d in c:
            spotify_text = d.text.replace('\n',' ')
            if artist!='RRRRRRRRRR':
                if (true_query in spotify_text.lower() and artist.lower() in spotify_text.lower()) or spotify_text.lower() in query:
                    print(spotify_text)
                    break
            else:
                if true_query in spotify_text.lower() or spotify_text.lower() in query :
                    print(spotify_text)
                    break
            i += 1
        print('i:',i)
        if i < 25:
            try:
                b = driver1.find_elements(By.XPATH,"//div[@data-testid='tracklist-row']//a[@draggable='false']")[i]
                driver1.get(b.get_attribute("href"))
                time.sleep(2)
                upstream = driver1.find_element(By.XPATH,"//body").text
                while 'upstream' in upstream.lower():
                    print(upstream.lower())
                    driver1.get(b.get_attribute("href"))
                    time.sleep(2)
                    upstream = driver1.find_element(By.XPATH,"//body").text
                popu, song = info()

            except Exception as e:
                popu = 'unpopular'
                song = result

        else:
            popu = 'unpopular'
            song = result
    result_variable.append((popu, song))

def findsong(key):
    result_list = []
    x_thread = threading.Thread(target=partial(findsong1,key,result_list))
 
    print("bắt đầu tìm song")
    x_thread.start()
    # Đợi tối đa 600 giây cho tiến trình con kết thúc
    x_thread.join(timeout=300)
    if x_thread.is_alive():
        # Nếu tiến trình con vẫn sống sau 600 giây, dừng nó và báo cáo
        x_thread.join()
        print('Thực thi quas 180s ')
        popu ='unpopular'
        song =result
    else:
        print('Thời gian thực thi không vượt quá 0 giây, tiếp tục xử lý.')##############################
    if result_list:
        popu, song = result_list[0] 
        print('có bài ', popu, ' ' ,song)
        return song,popu

def intent(key):
    if key not in datajs:
        global true_query
        datajs[key] = {}
        input_string = key
        encoded_string = urllib.parse.quote(input_string)
        spotify_link = f"https://open.spotify.com/search/{encoded_string}/tracks"
        driver1.get(spotify_link)
        time.sleep(1)
        upstream = driver1.find_element(By.XPATH,"//body").text
        while 'upstream' in upstream.lower():
            print(upstream.lower())
            driver1.get(spotify_link)
            time.sleep(2)
            upstream = driver1.find_element(By.XPATH,"//body").text
        try: 
            errormes = driver1.find_element(By.XPATH,"//h1").text
            print(errormes.lower())
        except:
            errormes = 'ddd'
            
        print(errormes.lower(), ' <> ')
        if 'found for' in errormes.lower() or 'not found' in errormes.lower() or 'No Podcasts & Shows' in errormes  :
            return 'RRRRRRRRRR','RRRRRRRRRR','RRRRRRRRRR'
        else:
            c = None
            tws = time.time()
            twr = 0
            while not c and twr < 120:
                c = driver1.find_elements(By.XPATH,"//div[@class='iCQtmPqY0QvkumAOuCjr']")
                time.sleep(skip)
                twr = time.time() - tws
            
            i = 0
            j = 0
            links = []
            print(11111)
            for d in c:
                spotify_text = d.text.replace('\n',' ')
                if true_query in spotify_text.lower():
                    b = driver1.find_elements(By.XPATH,"//div[@data-testid='tracklist-row']//a[@draggable='false']")[j]
                    links.append(b.get_attribute("href"))
                    print(spotify_text)
                    i += 1
                j += 1
                if i == 1:
                    break
            if not links:
                print('Truy vấn cả song và artist')
                artsong = False
                for d in c:
                    spotify_text = d.text.split('\n')[0]
                    if spotify_text.lower() in true_query:
                        print(spotify_text)
                        true_query = spotify_text.lower()
                        artsong = True
                        break
                if artsong:
                    i = 0
                    j = 0
                    links = []
                    print('Bắt đầu tìm kiếm với truy vấn',true_query)
                    for d in c:
                        spotify_text = d.text.replace('\n',' ')
                        if true_query in spotify_text.lower():
                            b = driver1.find_elements(By.XPATH,"//div[@data-testid='tracklist-row']//a[@draggable='false']")[j]
                            links.append(b.get_attribute("href"))
                            print(spotify_text)
                            i += 1
                        j += 1
                        if i == 5:
                            break
                
                    
            song_info_list = []
            for lik in links:
                driver1.get(lik)
                time.sleep(2)
                print(lik)
                upstream = driver1.find_element(By.XPATH,"//body").text
                while 'upstream' in upstream.lower():
                    print(upstream.lower())
                    driver1.get(lik)
                    time.sleep(2)
                    upstream = driver1.find_element(By.XPATH,"//body").text
              
                name = None
                art  = None
                while not name or not art:
                    try:
                        name = driver1.find_element(By.XPATH, "//h1").text
        #                 art  = driver1.find_elements(By.XPATH, "//a")[11].text
                        art = driver1.find_element(By.XPATH,"//section[@data-testid='track-page']//div/span/a").text
                    except:
                        time.sleep(skip)
                    
                try:
                    x = driver1.find_element(By.XPATH, "//span[@data-testid='playcount']")
                    y = x.text
                    x_text = y.replace(',', '')  # Loại bỏ dấu phẩy từ chuỗi
                    view_count = int(x_text)
                except Exception as e:
                    view_count = 0
                    y = None
                if view_count >= 4000000:
                    popu = "popular"
                else:
                    popu = "unpopular"
                if y:
                    op_song = f"The user is looking for song {name} by {art} (+{y} streams in Spotify) "
                else:
                    op_song = f"The user is looking for song {name} by {art}"
                intend = f"{name} by {art}"
                song_info = {}
                song_info['popu'] = popu
                song_info['op_song'] = op_song
                song_info['view_count'] = view_count
                song_info['art'] = art
                song_info['intend'] = intend
                print(op_song)
    
                # Thêm từ điển vào danh sách
                song_info_list.append(song_info)
    
                sorted_song = sorted(song_info_list, key=lambda x: x['view_count'], reverse=True)
            try:
                datajs[key]['op_song'] = sorted_song[0]['op_song']
                datajs[key]['art'] = sorted_song[0]['art']
                datajs[key]['intend'] = sorted_song[0]['intend']
            except Exception as e:
                datajs[key]['op_song'] = 'RRRRRRRRRR'
                datajs[key]['art'] = 'RRRRRRRRRR'
                datajs[key]['intend'] = 'RRRRRRRRRR'
    else:
        print('truy van ton tai')
        
    return datajs[key]['op_song'], datajs[key]['art'], datajs[key]['intend'] 
    
def intentv2(key):
    if key not in datajs:
        global true_query
        datajs[key] = {}
        input_string = key
        encoded_string = urllib.parse.quote(input_string)
        spotify_link = f"https://open.spotify.com/search/{encoded_string}/tracks"
        driver1.get(spotify_link)
        time.sleep(1)
        upstream = driver1.find_element(By.XPATH,"//body").text
        while 'upstream' in upstream.lower():
            print(upstream.lower())
            driver1.get(spotify_link)
            time.sleep(2)
            upstream = driver1.find_element(By.XPATH,"//body").text
        try: 
            errormes = driver1.find_element(By.XPATH,"//h1").text
            print(errormes.lower())
        except:
            errormes = 'ddd'
            
        print(errormes.lower(), ' <> ')
        if 'found for' in errormes.lower() or 'not found' in errormes.lower() or 'No Podcasts & Shows' in errormes  :
            return 'RRRRRRRRRR','RRRRRRRRRR','RRRRRRRRRR'
        else:
            c = None
            tws = time.time()
            twr = 0
            while not c and twr < 120:
                c = driver1.find_elements(By.XPATH,"//div[@class='iCQtmPqY0QvkumAOuCjr']")
                time.sleep(skip)
                twr = time.time() - tws
            
            i = 0
            j = 0
            links = []
            print(11111)
            for d in c:
                spotify_text = d.text.replace('\n',' ')
                if true_query in spotify_text.lower():
                    b = driver1.find_elements(By.XPATH,"//div[@data-testid='tracklist-row']//a[@draggable='false']")[j]
                    links.append(b.get_attribute("href"))
                    print(spotify_text)
                    i += 1
                j += 1
                if i == 1:
                    break
            if not links:
                print('Truy vấn cả song và artist')
                artsong = False
                for d in c:
                    spotify_text = d.text.split('\n')[0]
                    if spotify_text.lower() in true_query:
                        print(spotify_text)
                        true_query = spotify_text.lower()
                        artsong = True
                        break
                if artsong:
                    i = 0
                    j = 0
                    links = []
                    print('Bắt đầu tìm kiếm với truy vấn',true_query)
                    for d in c:
                        spotify_text = d.text.replace('\n',' ')
                        if true_query in spotify_text.lower():
                            b = driver1.find_elements(By.XPATH,"//div[@data-testid='tracklist-row']//a[@draggable='false']")[j]
                            links.append(b.get_attribute("href"))
                            print(spotify_text)
                            i += 1
                        j += 1
                        if i == 5:
                            break
                
                    
            song_info_list = []
            for lik in links:
                driver1.get(lik)
                time.sleep(2)
                print(lik)
                upstream = driver1.find_element(By.XPATH,"//body").text
                while 'upstream' in upstream.lower():
                    print(upstream.lower())
                    driver1.get(lik)
                    time.sleep(2)
                    upstream = driver1.find_element(By.XPATH,"//body").text
              
                name = None
                art  = None
                while not name or not art:
                    try:
                        name = driver1.find_element(By.XPATH, "//h1").text
        #                 art  = driver1.find_elements(By.XPATH, "//a")[11].text
                        art = driver1.find_element(By.XPATH,"//section[@data-testid='track-page']//div/span/a").text
                    except:
                        time.sleep(skip)
                    
                try:
                    x = driver1.find_element(By.XPATH, "//span[@data-testid='playcount']")
                    y = x.text
                    x_text = y.replace(',', '')  # Loại bỏ dấu phẩy từ chuỗi
                    view_count = int(x_text)
                except Exception as e:
                    view_count = 0
                    y = None
                if view_count >= 4000000:
                    popu = "popular"
                else:
                    popu = "unpopular"
                if y:
                    op_song = f"The user is looking for song {name} by {art} (+{y} streams in Spotify) "
                else:
                    op_song = f"The user is looking for song {name} by {art}"
                intend = f"{name} by {art}"
                song_info = {}
                song_info['popu'] = popu
                song_info['op_song'] = op_song
                song_info['view_count'] = view_count
                song_info['art'] = art
                song_info['intend'] = intend
                print(op_song)
    
                # Thêm từ điển vào danh sách
                song_info_list.append(song_info)
    
                sorted_song = sorted(song_info_list, key=lambda x: x['view_count'], reverse=True)
            try:
                datajs[key]['op_song'] = sorted_song[0]['op_song']
                datajs[key]['art'] = sorted_song[0]['art']
                datajs[key]['intend'] = sorted_song[0]['intend']
            except Exception as e:
                datajs[key]['op_song'] = 'RRRRRRRRRR'
                datajs[key]['art'] = 'RRRRRRRRRR'
                datajs[key]['intend'] = 'RRRRRRRRRR'
    else:
        print('truy van ton tai')
        
    return datajs[key]['op_song'], datajs[key]['art'], datajs[key]['intend'] 
#Lấy dữ liệu từ trang
def data():
    dataset = {}
    # Chuẩn bị dữ liệu đâu f
    output = None
    while not output:
        output_g = driver.find_element(By.XPATH,"//h4")
        output = output_g.text
        time.sleep(skip)

    link = None
    while not link:
        link_g = driver.find_element(By.XPATH,"//h4/a")
        link = link_g.get_attribute("href")
        time.sleep(skip)    

    output_type = None
    while not output_type:
        output_type_g = driver.find_element(By.XPATH,"//span[@class='text-muted']")
        output_type = output_type_g.text.strip('()')
        output_type = output_type.lower()

    list_items = driver.find_elements(By.XPATH,"//li[@class='list-group-item']")
    data = {}
    for item in list_items:
        x = item.find_elements(By.XPATH,"./div/div") 
        key = x[0].text.strip()
        value = x[1].text.strip()
        data[key] = value

    query_type = data['Query type']
    try:
        disambiguation = data['Disambiguation']
    except Exception as e:
        disambiguation = None
    try:
        query = data['Correct Spelling']
    except Exception as e:
        input_g = driver.find_element(By.XPATH,"//h1/strong")
        query = input_g.text
   
    try:
        if 'music' in output_type:
            artist_g = driver.find_element(By.XPATH,"//p")
            artist = artist_g.text 
            result = output + ' by ' + artist
        else:
            artist_g = driver.find_element(By.XPATH,"//div[@class='affinity-artist-name mb-2']")
            artist = artist_g.text 
            result = output + ' by ' + artist
    except Exception as e:
        result = output
        artist = 'RRRRRRRRRR'
    if 'artist' in output_type.lower():
        result = query
    dataset = {
    'output_type': output_type,
    'query_type': query_type,
    'disambiguation': disambiguation,
    'query': query,
    'link': link,
    'output': output,
    'artist' : artist,
    'result' : result
    }
    return dataset


    
def artist_type():
    if 'RRRRRRRRR' not in artist:
        if (query in artist.lower()) or check_output(query,output.lower()):
            if 'remix' in output.lower():
                rank('924')
                comment = f" The result is the remix version of {output_type} {output} that the artist the user is looking for is featured on. Therefore, the result can be rated as 'Acceptable'"
                write_comment(comment)
            elif 'cover' in output.lower():
                rank('924')
                comment = f" The result is the cover version of {output_type} {output} that the artist the user is looking for is featured on. Therefore, the result can be rated as 'Acceptable'"
                write_comment(comment)
            else:
                rank('922')
                comment = f" The result is the {output_type} {output} that the artist the user is looking for is featured on. Therefore, the result can be rated as 'Exellent'"
                write_comment(comment)
        elif true_query in output.lower():
            rank('924')
            comment = f" but the result is {output_type} {result} which matching part of the title of the query. Therefore, the result can be rated as 'Acceptable'"
            write_comment(comment)
        else:
            rank('925')
            comment = f" but the result is {output_type} {result} which not relevant to the intended artist. Therefore, the result can be rated as 'Off-topic'"
            write_comment(comment)
    else:
        if 'station' in output_type:
            if query in output.lower():
                rank('922')
                comment = f" The result is the {output_type} {output} which Composer station by Apple Music Classical. Therefore, the result can be rated as 'Exellent'"
                write_comment(comment)
            else:
                rank('925')
                comment = f" but the result is {output_type} {result} which not relevant to the intended artist  so the result can be rated as 'Off-Topic'"
                write_comment(comment)
        elif 'radio' in output_type:
            if query in output.lower():
                rank('922')
                comment = f" The result is the {output_type} of {output}. Therefore, the result can be rated as 'Exellent'"
                write_comment(comment)
            else:
                rank('925')
                comment = f" but the result is {output_type} {result} which not relevant to the intended artist  so the result can be rated as 'Off-Topic'"
                write_comment(comment)
        elif 'play' in output_type:
            
            if query in output.lower() and (('essentials' in output.lower()) or ('deep cuts'in output.lower()) or ('next steps' in output.lower())):
                rank('922')
                comment = f"The result is the playlist {output}  that featuring only the intended artist. so the result can be rated as 'Exellent' "
                write_comment(comment)
            else:
                a = feature(link,artist,query)
                if a:
        
                    rank('923')
                    comment = f"The result is the high-quality playlist {output}  that feature the intended song ({a}) AND songs by other artists in similar genre. so the result can be rated as 'Good' "
                    write_comment(comment)
                else:
                    rank('925')
                    comment = f" but the result is {output_type} {result} which not relevant to the intended artist  so the result can be rated as 'Off-Topic'"
                    write_comment(comment)
        elif 'art' in output_type:
            if query in output.lower() or ( disambiguation and (disambiguation.lower() in output.lower() or output.lower() in disambiguation.lower())) :
                rank('921')
                comment = f"The result is the artist page for {output} which is the user looking for. so the result can be rated as 'Perfect' "
                write_comment(comment)
            else:
                rank('925')
                comment = f" but the result is {output} which not relevant to the intended artist  so the result can be rated as 'Off-Topic'"
                write_comment(comment)
        else:
            rank('925')
            comment = f" but the result is {output_type} {result} which not relevant to the intended artist  so the result can be rated as 'Off-Topic'"
            write_comment(comment)
                
def soundtrack():
    driver2.get(link)
    time.sleep(2)
    print(driver2.find_element(By.XPATH,"//h1").text)
    if "can’t be found" in driver2.find_element(By.XPATH,"//h1").text:
        return False
    else:
        a = None
        print('Đã mở album/ playlist. Ktra xem có tồn tại bài hát không')
        tws = time.time()
        twr = 0
        while not a  and twr < 120:
            a = driver2.find_element(By.XPATH,"//h1").text
            time.sleep(skip)
            twr = time.time() - tws
        if 'original' in a.lower():
            return True
        else:
            return False
        
def songin(key):
    print('songin',key)
    driver2.get(link)
    time.sleep(2)
    print(driver2.find_element(By.XPATH,"//h1").text)
    if "can’t be found" in driver2.find_element(By.XPATH,"//h1").text:
        return False
    else:
        a = None
        print('Đã mở album/ playlist. Ktra xem có tồn tại bài hát không')
        tws = time.time()
        twr = 0
        while not a and twr < 120:
            a = driver2.find_element(By.XPATH,"//h1").text
            time.sleep(skip)
            twr = time.time() - tws
        if a.lower() in key:
            return True
        else:
            return False
def various():
    print('various')
    driver2.get(link)
    time.sleep(2)
    print(driver2.find_element(By.XPATH,"//h1").text)
    if "can’t be found" in driver2.find_element(By.XPATH,"//h1").text or '찾으시는 페이지를 찾을 수 없습니' in driver2.find_element(By.XPATH,"//h1").text:
        return False
    else:
        a = None
        print('Đã mở album/ playlist. Ktra xem có tồn tại bài hát không')
        tws = time.time()
        twr = 0
        while not a and twr < 120:
            try:
                a = driver2.find_element(By.XPATH,"//div[@class='headings__subtitles svelte-1ug8xq0']").text
                time.sleep(skip)
                twr = time.time() - tws
            except:
                time.sleep(skip)
                twr = time.time() - tws
        if 'various' in a.lower() or 'apple' in a.lower():
            return True
        else:
            return False
# Kiểm tra xem bài hát có ở trong album , playlít không
def feature(link,artist,query):
    album = link
    driver2.get(album)
    time.sleep(2)
    if "can’t be found" in driver2.find_element(By.XPATH,"//h1").text or '찾으시는 페이지를 찾을 수 없습니' in driver2.find_element(By.XPATH,"//h1").text:
        return None
    else:
        a = None
        b = None
        print('Đã mở album/ playlist. Ktra xem có tồn tại bài hát không')
        tws = time.time()
        twr = 0
        while (not a or not b) and twr < 120:
            a = driver2.find_elements(By.XPATH,"//div[@class='songs-list-row__song-wrapper svelte-4hjdmk']")
            b = driver2.find_elements(By.XPATH,"//div[@class='songs-list-row__song-name svelte-4hjdmk']")
            time.sleep(skip)
            twr = time.time() - tws
            print('dang doi 1')
        
        print(len(a),'<>',len(b))
        print()
        lalbum = []
        lalbum2 = []
        
        for i in b:
            lalbum2.append(i.text)
        for i in a:
        #         print(i.text)
            if '\n' in i.text:
                lalbum.append(i.text.replace('\n', ' by '))
            else:
                if artist!='RRRRRRRRRR':
                    lalbum.append(i.text+ ' by ' + artist)
                else:
                    lalbum.append(i.text)
        print('bài đầu tiên trong album/playlist là : ',lalbum[0])
        for i in range(0,len(lalbum)):
            if true_query in lalbum2[i].lower():
                return(lalbum[i])
                break
    return None
    
def intent2(key):
    if key not in datajs:
        datajs[key] = {}
        input_string = key
        encoded_string = urllib.parse.quote(input_string)
        spotify_link = f"https://open.spotify.com/search/{encoded_string}/tracks"
        driver1.get(spotify_link)
        time.sleep(1)
        upstream = driver1.find_element(By.XPATH,"//body").text
        while 'upstream' in upstream.lower():
            print(upstream.lower())
            driver1.get(spotify_link)
            time.sleep(2)
            upstream = driver1.find_element(By.XPATH,"//body").text
        c = None
        tws = time.time()
        twr = 0
        while not c and twr < 120:
            c = driver1.find_elements(By.XPATH,"//div[@class='iCQtmPqY0QvkumAOuCjr']")
            time.sleep(skip)
            twr = time.time() - tws
        
        i = 0
        j = 0
        links = []
        print(11111)
        for d in c:
            spotify_text = d.text.replace('\n',' ')
            if true_query in spotify_text.lower():
                b = driver1.find_elements(By.XPATH,"//div[@data-testid='tracklist-row']//a[@draggable='false']")[j]
                links.append(b.get_attribute("href"))
                print(spotify_text)
                i += 1
            j += 1
            if i == 3:
                break
        song_info_list = []
        for lik in links:
            driver1.get(lik)
            time.sleep(2)
            print(lik)
            upstream = driver1.find_element(By.XPATH,"//body").text
            while 'upstream' in upstream.lower():
                print(upstream.lower())
                driver1.get(lik)
                time.sleep(2)
                upstream = driver1.find_element(By.XPATH,"//body").text
            name = None
            art  = None
            while not name or not art:
                try:
                    name = driver1.find_element(By.XPATH, "//h1").text
    #                 art  = driver1.find_elements(By.XPATH, "//a")[11].text
                    art = driver1.find_element(By.XPATH,"//section[@data-testid='track-page']//div/span/a").text
                except:
                    time.sleep(skip)
                
            try:
                x = driver1.find_element(By.XPATH, "//span[@data-testid='playcount']")
                y = x.text
                try:
                    x_text = y.replace(',', '')  # Loại bỏ dấu phẩy từ chuỗi
                    view_count = int(x_text)
                except:
                    view_count = 0
            except Exception as e:
                view_count = 0
                y = None
            if view_count >= 4000000:
                popu = "popular"
            else:
                popu = "unpopular"
            if y:
                op_song = f" song {name} by {art} (+{y} streams in Spotify) "
            else:
                op_song = f" song {name} by {art}"
            intend = f"{name} by {art}"
            song_info = {}
            song_info['popu'] = popu
            song_info['op_song'] = op_song
            song_info['view_count'] = view_count
            song_info['art'] = art
            song_info['intend'] = intend
            print(op_song)

            # Thêm từ điển vào danh sách
            song_info_list.append(song_info)

            sorted_song = sorted(song_info_list, key=lambda x: x['view_count'], reverse=True)
        try:
            datajs[key]['op_song'] = sorted_song[0]['op_song']
            datajs[key]['art'] = sorted_song[0]['art']
            datajs[key]['intend'] = sorted_song[0]['intend']
        except Exception as e:
            datajs[key]['op_song'] = 'RRRRRRRRRR'
            datajs[key]['art'] = 'RRRRRRRRRR'
            datajs[key]['intend'] = 'RRRRRRRRRR'
    else:
        print('truy van ton tai')
        
    return datajs[key]['op_song'], datajs[key]['art'], datajs[key]['intend']    
    
def intent3(key):
    input_string = key
    encoded_string = urllib.parse.quote(input_string)
    spotify_link = f"https://open.spotify.com/search/{encoded_string}/artists"
    driver1.get(spotify_link)
    time.sleep(2)
    upstream = driver1.find_element(By.XPATH,"//body").text
    while 'upstream' in upstream.lower():
        print(upstream.lower())
        driver1.get(spotify_link)
        time.sleep(2)
        upstream = driver1.find_element(By.XPATH,"//body").text
    try: 
        errormes = driver1.find_element(By.XPATH,"//h1").text
        print(errormes.lower())
    except:
        errormes = 'ddd'
    print(errormes.lower(), ' <> ')
    if 'found for' in errormes.lower() or 'not found' in errormes.lower() or 'No Podcasts & Shows' in errormes :
        return 'RRRRRRRRRR','RRRRRRRRRR','RRRRRRRRRR'
    else:
        c = None
        d = None
        tws = time.time()
        twr = 0
        while (not c or not d) and twr < 120:
            try:
                c = driver1.find_element(By.XPATH,"//div[@data-testid='grid-container']")
                d = driver1.find_element(By.XPATH,"//div[@data-testid='search-category-card-0']")
                e = c.find_element(By.XPATH,".//a").get_attribute("href")
            except:
                time.sleep(skip)
                twr = time.time() - tws
        print(d)
        if true_query in d.text.lower():
            driver1.get(e)
            time.sleep(2)
            upstream = driver1.find_element(By.XPATH,"//body").text
            while 'upstream' in upstream.lower():
                print(upstream.lower())
                driver1.get(e)
                time.sleep(2)
                upstream = driver1.find_element(By.XPATH,"//body").text
            name = None
            while not name:
                try:
                    name = driver1.find_element(By.XPATH, "//section/div/div/div/span[@class='Ydwa1P5GkCggtLlSvphs']")
                except:
                    time.sleep(skip)
                    print('waiting')
            d = name.text
            if 'monthly listeners' in d:
                e = d.replace(' monthly listeners','')
            elif 'monthly listener' in d:
                e = d.replace(' monthly listener','')
            print(e)
            try:
                x_text = e.replace(',', '')  # Loại bỏ dấu phẩy từ chuỗi
                view_count = int(x_text)
            except Exception as e:
                view_count = 0
                e = None
            art = driver1.find_element(By.XPATH, "//h1").text
            if view_count >= 500000:
                popu = "popular"
            else:
                popu = "unpopular"
            if e:
                op_art = f"artist page for {art} (+{e} monthly listeners in Spotify) "
            else:
                op_art = f"artist page for {art} "
            try:
                first = driver1.find_element(By.XPATH,"//div[@aria-rowindex='1']//a").text
                viewf = driver1.find_element(By.XPATH,"//div[@aria-colindex='3']").text
            except:
                first = 'RRRRRRRRRR'
                viewf = 'RRRRRRRRRR'
            if 'un' not in popu:
                return op_art, first, viewf
            else:
                return 'RRRRRRRRRR','RRRRRRRRRR','RRRRRRRRRR'
    return 'RRRRRRRRRR','RRRRRRRRRR','RRRRRRRRRR'
    
def findart(key):
    input_string = key
    encoded_string = urllib.parse.quote(input_string)
    spotify_link = f"https://open.spotify.com/search/{encoded_string}/artists"
    driver1.get(spotify_link)
    time.sleep(2)
    upstream = driver1.find_element(By.XPATH,"//body").text
    while 'upstream' in upstream.lower():
        print(upstream.lower())
        driver1.get(spotify_link)
        time.sleep(2)
        upstream = driver1.find_element(By.XPATH,"//body").text
        
    try: 
        errormes = driver1.find_element(By.XPATH,"//h1").text
    except:
        errormes = 'ddd'
    print(errormes.lower(), ' <> ')
    if 'found for' in errormes.lower() or 'not found' in errormes.lower() or 'No Podcasts & Shows' in errormes :
        return 'RRRRRRRRRR','RRRRRRRRRR'
    else:
        c = None
        d = None
        tws = time.time()
        twr = 0
        while (not c or not d) and twr < 120:
            try:
                c = driver1.find_element(By.XPATH,"//div[@data-testid='grid-container']")
                d = driver1.find_element(By.XPATH,"//div[@data-testid='search-category-card-0']")
                e = c.find_element(By.XPATH,".//a").get_attribute("href")
            except:
                time.sleep(skip)
                twr = time.time() - tws
        print(d)
        if true_query in d.text.lower():
            driver1.get(e)
            time.sleep(2)
            upstream = driver1.find_element(By.XPATH,"//body").text
            while 'upstream' in upstream.lower():
                print(upstream.lower())
                driver1.get(e)
                time.sleep(2)
                upstream = driver1.find_element(By.XPATH,"//body").text
            name = None
            while not name:
                try:
                    name = driver1.find_element(By.XPATH, "//section/div/div/div/span[@class='Ydwa1P5GkCggtLlSvphs']")
                except:
                    time.sleep(skip)
                    print('waiting')
            d = name.text
            e = d.replace(' monthly listeners','')
            print(e)
            try:
                x_text = e.replace(',', '')  # Loại bỏ dấu phẩy từ chuỗi
                view_count = int(x_text)
            except Exception as e:
                view_count = 0
                e = None
            art = driver1.find_element(By.XPATH, "//h1").text
            if view_count >= 500000:
                popu = "popular"
            else:
                popu = "unpopular"
            if e:
                op_art = f"artist page for {art} (+{e} streams in Spotify) "
            else:
                op_art = f"artist page for {art} "

        return popu, op_art
    return 'RRRRRRRRRR','RRRRRRRRRR'
def data1():
    dataset = {}
    list_items = driver.find_elements(By.XPATH,"//li[@class='list-group-item']")
    data = {}
    for item in list_items:
        x = item.find_elements(By.XPATH,"./div/div") 
        key = x[0].text.strip()
        value = x[1].text.strip()
        data[key] = value
    try:
        xxx = data['Language']
    except:
        xxx = None
    if 'Eng' not in xxx:
    # Chuẩn bị dữ liệu đâu f
        output = None
        while not output:
            output_g = driver.find_element(By.XPATH,"//h4")
            output = output_g.text
            output = translate(output)
            time.sleep(skip)
    
        link = None
        while not link:
            link_g = driver.find_element(By.XPATH,"//h4/a")
            link = link_g.get_attribute("href")
            time.sleep(skip)    
    
        output_type = None
        while not output_type:
            output_type_g = driver.find_element(By.XPATH,"//span[@class='text-muted']")
            output_type = output_type_g.text.strip('()')
            output_type = output_type.lower()

    
    
        query_type = data['Query type']
        try:
            disambiguation = data['Disambiguation']
            disambiguation = translate(disambiguation)
        except Exception as e:
            disambiguation = None
        try:
            query = data['Translation']
        except Exception as e:
            try:
                
                query = data['Correct Spelling']
            except:
                try:
                    input_g = driver.find_element(By.XPATH,"//h1/strong/span")
                    query = input_g.get_attribute("data-original-title")
                except:
                    input_g = driver.find_element(By.XPATH,"//h1/strong")
                    query = input_g.text
        
        try:
            if 'music' in output_type:
                artist_g = driver.find_element(By.XPATH,"//p")
                artist = artist_g.text 
                artist = translate(artist)
                result = output + ' by ' + artist
            else:
                artist_g = driver.find_element(By.XPATH,"//div[@class='affinity-artist-name mb-2']")
                artist = artist_g.text 
                artist = translate(artist)
                result = output + ' by ' + artist
        except Exception as e:
            result = output
            artist = 'RRRRRRRRRR'
        if 'artist' in output_type.lower():
            result = query
    else:
        output = None
        while not output:
            output_g = driver.find_element(By.XPATH,"//h4")
            output = output_g.text
            time.sleep(skip)
    
        link = None
        while not link:
            link_g = driver.find_element(By.XPATH,"//h4/a")
            link = link_g.get_attribute("href")
            time.sleep(skip)    
    
        output_type = None
        while not output_type:
            output_type_g = driver.find_element(By.XPATH,"//span[@class='text-muted']")
            output_type = output_type_g.text.strip('()')
            output_type = output_type.lower()
    
        
    
        query_type = data['Query type']
        try:
            disambiguation = data['Disambiguation']
        except Exception as e:
            disambiguation = None
        try:
            query = data['Correct Spelling']
        except Exception as e:
            input_g = driver.find_element(By.XPATH,"//h1/strong")
            query = input_g.text
       
        try:
            if 'music' in output_type:
                artist_g = driver.find_element(By.XPATH,"//p")
                artist = artist_g.text 
                result = output + ' by ' + artist
            else:
                artist_g = driver.find_element(By.XPATH,"//div[@class='affinity-artist-name mb-2']")
                artist = artist_g.text 
                result = output + ' by ' + artist
        except Exception as e:
            result = output
            artist = 'RRRRRRRRRR'
        if 'artist' in output_type.lower():
            result = query
        
    dataset = {
    'output_type': output_type,
    'query_type': query_type,
    'disambiguation': disambiguation,
    'query': query,
    'link': link,
    'output': output,
    'artist' : artist,
    'result' : result
    }
    return dataset

# %%
def runcodetranning():
    global output
    global link
    global query
    global disambiguation
    global query_type
    global output_type
    global true_query
    global result
    global artist
   
    delete_comment()
    output = None
    link = None
    query = None
    disambiguation = None
    query_type = None
    output_type = None
    result = None
    true_query = None
    artist = 'RRRRRRRRRR'   
    

    #Chuẩn bị dữ liệu
    dataset = data()
    output = dataset['output']
    link = dataset['link']
    query = dataset['query'].lower()
    query = query.replace("’","'")
    disambiguation = dataset['disambiguation']
    query_type = dataset['query_type'].lower()
    true_query = query
    if 'ambiguous' in query_type:
        if disambiguation:
            if 'genre' in disambiguation:
                query_type = 'genre'
                print(' ambiguous of genre')
            elif 'song' in disambiguation:
                query_type = 'song na'
                print(' ambiguous of song')
            elif 'artist' in disambiguation:
                query_type = 'artist'
                print('ambiguous of artist')
    output_type = dataset['output_type'].lower()
    print(query_type,'-->',output_type)
    result = dataset['result']
    artist = dataset['artist']  
    print(dataset)
    print(result)
    #dua ra muc dich tim kiem neu co dinh huong
    if disambiguation:
        if 'intent' in disambiguation.lower():
            try:
                write_comment(f"{disambiguation}. ")
            except:
                write_comment(f"The user is looking for artist {query}. ")
        else:
            try:
                write_comment(f"The user is looking for {disambiguation}. ")
            except:
                write_comment(f"The user is looking for artist {query}. ")
    #Kiểm tra xem là truy vấn artist không
    if 'song' in query_type:
        if not disambiguation:
            print('Tìm hàng đầu đã')
            try:
                print(intent(query))
            except Exception as e:
                print('Lỗi intent')
            iintent = 0
            while not datajs[query] or 'RRRRRRRRR' in intent(query)[2] :
                iintent+=1
                if iintent > 5:
                    try:
                        intentjs[query].append(driver.current_url)
                    except:
                        intentjs[query] = []
                        intentjs[query].append(driver.current_url)
                    break
                if query in datajs:
                    del datajs[query]
                print(intent(query))



    # if 'Artist' in query_type:
    if 'artist' in query_type:
        print('arist query')
        if not disambiguation:
            write_comment(f"The user is looking for artist {query}. ")
        artist_type()


    #If truy vấn song
    #Mục đích để biến art để kiểm tra xem bài hát có phải là 1 tác phẩm khác của0 tác giả
    # Mục đích của biến intend để ktra xem bài đó có phải bài intend ko
    elif 'song' in query_type:
        # dua ra user looking
        if not disambiguation:
            print('Đang tìm bài hàng đầu')
            com,art,intented = intent(query)
            if com != 'RRRRRRRRRR':
                print(com,art,intented)# comment cho baì hàng đầu, aritst của bài hàng đầu, hàng đầu
                write_comment(intent(query)[0])
                print('Đã in ra bài hát hàng đầu')
        else:
            print('Đã in ra disambiguation')
            art = disambiguation
            intented = disambiguation.replace("'",'')

        if 'album' in output_type and 'single' in output.lower():
            b = single(link,artist)
        else:
            b = None
        print('album single is',b)
        if 'artist' in output_type:
            #TH1,2 - artist search

            ###############################
            if art.lower() in output.lower() or output.lower() in art.lower(): 
                write_comment(f"The result is the artist page for {output} who performed the intend song so the result is rated Good")
                rank('923')
            else:
                song,popu = findsong(true_query+ ' ' + output)
                print('Tìm ra bài ',popu, ' tên là ', song)  
                if true_query in song and output in song:

                    if popu == 'unpopular':
                        write_comment(f"The result is the artist page for {output} who performed unpopular {song} so the result is rated Off-Topic")
                        rank('925')
                    else:
                        write_comment(f"The result is the artist page for {output} who performed popular {song} so the result is rated Acceptable")
                        rank('924')
                else:                                           
                    write_comment(f"The result is the artist page for {output} that is not related to the intend song so the result is rated Off-Topic")
                    rank('925')

        elif 'song' in output_type or 'music' in output_type:
            if true_query in output.lower():
                print('output khớp query')
                if art.lower() in artist.lower() or artist.lower() in art.lower() or check_output(art.lower(),output.lower()):
                    print('khớp mục đích truy vấn')
                    if 'acoustic' in output.lower():
                        rank('922')
                        write_comment(f"The result is song {output} by {artist} which is acoustic version of the primary intend so we can rate the result as Exellent ")
                    elif 'guitar' in output.lower():
                        rank('922')
                        write_comment(f"The result is song {output} by {artist} which is guitar version of the primary intend so we can rate the result as Exellent ")
                    elif 'piano' in output.lower():
                        rank('922')
                        write_comment(f"The result is song {output} by {artist} which is piano version of the primary intend so we can rate the result as Exellent ")
                    elif 'violin' in output.lower():
                        rank('922')
                        write_comment(f"The result is song {output} by {artist} which is violin version of the primary intend so we can rate the result as Exellent ")
                    elif 'music' in output_type:
                        rank('922')
                        write_comment(f"The result is {output_type} {output} by {artist} which is music video of the primary intend so we can rate the result as Exellent ")
                    else:
                        rank('921')
                        write_comment(f"The result is song is the user is looking for so we can rate the result as Perfect ")
                else:
                    song,popu = findsong(output+ ' ' + artist)##########################
                    print(song, popu)
                    if 'un' not in popu:
                        #TH3 - song search  - popu
                        rank('923')
                        write_comment(f"The result is popular {song} that satisfies the secondary intent so we can rate the result as Good")

                    else:
                        #TH4 - song search - unpopu
                        rank('924')
                        write_comment(f"The result is unpopular {song} so we can rate the result as Acceptable")

            elif art.lower() in artist.lower() or artist.lower() in art.lower() or check_output(art.lower(),output.lower()) or artist.lower() in query:
                #TH5 - other music of  artist
                print('another music')            
                rank('923')
                write_comment(f"The result is {output_type} {result} which is other music of the artist so we can rate the result as Good")

            else:
                #TH6 ko lien quan 
                rank('925')
                print(output.lower(), ' <> ', query)
                write_comment(f"The result is the {output_type} {result} which not relevant to the query so we can rate the result as Off-Topic")
        elif 'album' in output_type or 'play' in output_type:
            kt = 0
            kt_album1 = 0
            print('album1')
           #########################################
            if b:
                print('album2')
                if true_query in output.lower():
                    if art.lower() in artist.lower() or artist.lower() in art.lower() or check_output(art.lower(),output.lower()):
                        rank('921')
                        write_comment(f"The result is single album is the user is looking for so we can rate the result as Perfect ")

                    else: 
                        song,popu = findsong(b)##########################
                        print(song, popu)
                        if 'un' not in popu:
                        #TH3 - song search  - popu
                            rank('923')
                            write_comment(f"The result is popular single album {song} that satisfies the secondary intent so we can rate the result as Good")
                        else:
                            #TH4 - song search - unpopu
                            rank('924')
                            write_comment(f"The result is unpopular single album {song} so we can rate the result as Acceptable")
                elif art.lower() in artist.lower() or artist.lower() in art.lower() or check_output(art.lower(),output.lower()) or artist.lower() in query:
                    #TH5 - other music of  artist
                    print('another music')            
                    rank('923')
                    write_comment(f"The result is {output_type} {result} which is other music of the artist so we can rate the result as Good")
                else:
                    rank('925')
                    write_comment(f"The result is the {output_type} {result} which not relevant to the query .Therefore, the result can be rated as 'Off-Topic'")
            ##################################################
            else:
                if  true_query in output.lower():
                    kt = 1 
                    print('kt run')
                print('album3')
                if 'album' in output_type and (art.lower() in artist.lower() or artist.lower() in art.lower() or check_output(art.lower(),output.lower())):
                    kt_album1 = 1 # dungf để xem nó có phải chứa hay chỉ là bài khác của artist
                print('truy vấn album và playlist')
                a = feature(link,artist,query)###########################
                if a:
                    print(a.lower(),'<>', intented.lower())
                    song,popu = findsong(a.replace('by ',''))##############################
                    print('có bài ', popu, ' ' ,song)
                    if  song.lower() in intented.lower() or intented.lower() in song.lower() or a.lower() in intented.lower() or intented.lower() in a.lower() or (query in intented.lower() and artist.lower() in intented.lower()):
                        if 'play' in output_type:
                            #th7 - playlist chua bai hat du dinh
                            rank('923')
                            write_comment(f"The result is the high-quality {output_type} {result} that contains the intend song {a}. Therefore, the result can be rated as 'Good'")

                        else:
                            #th8 - album cua bai hat du dinh
                            rank('923')
                            write_comment(f"The result is the album of the intend song {a}. Therefore, the result can be rated as 'Good'")
                    elif kt_album1 == 1:
                        print('another music')            
                        rank('923')
                        write_comment(f"The result is {output_type} {result} which is other music of the artist so we can rate the result as Good")

                    else:
                        song,popu = findsong(a.replace('by ',''))##############################
                        print('có bài ', popu, ' ' ,song)
                        if 'un' not in popu:
                            #th10 - chua bai noi tieng
                            rank('924')
                            write_comment(f"The result is the {output_type} {result} that contains the popular {song} which is rated as 'Good'. Therefore, the result can be rated as 'Acceptable'")
                        else:
                            if kt == 1:
                                rank('924')
                                write_comment(f"The result is the unpopular {output_type} {result} that matching title of query so we can rate the result as Acceptable")

                            else:
                                #th9 chua bai khong noi tieng
                                rank('925')
                                write_comment(f"The result is the {output_type} {result} that contains the unpopular {a} which is rated as 'Acceptable'. Therefore, the result can be rated as 'Off-Topic'")

                else:
                    print('Không có bài đó trong album/playlist')
                    if true_query in output.lower():
                        #th11 - khop title nhung ko noi
                        rank('924')
                        write_comment(f"The result is unpopular {output_type} {result} that matching title of query so we can rate the result as Acceptable")
                    else:
                        if various():
                        #th12 - ko chua nhung chung genre 
                            rank('924')
                            write_comment(f"The result is the {output_type} {result} that don’t feature the intended song BUT fit in the genre of the intended song .Therefore, the result can be rated as 'Acceptable'")
                        else:
                            rank('925')
                            write_comment(f"The result is the {output_type} {result} which not relevant to the query .Therefore, the result can be rated as 'Off-Topic'")

        else:
            rank('925')
            print(f'The result is the {output_type} {result} which not relevant to the query so we can rate the result as Off-Topic  ')



    elif 'genre' in query_type: 
        if not disambiguation:
            write_comment(f"The user is looking for music genre of {query}. ")
        if 'song' in output_type or 'music' in output_type or 'artist' in output_type:
            rank("924")
            write_comment(f"The result is {output_type} {result} that in the intend genre - {query}. So we can rate the result as Acceptable")
        elif 'album' in output_type:
            rank("922")
            write_comment(f"The result is popular {output_type} {result} that in the intend genre - {query}. So we can rate the result as Exellent")
        elif 'playlist' in output_type:
            linkjs.append(driver.current_url)
            with open(link_path, 'w') as json_file:
                json.dump(linkjs, json_file) 
            rank('922')
            write_comment(f"The result is {output_type} {result} which  in the intended genre that is a little specific on activity/mood/era/occasion/year. So we can rate the result as Exellent")
        else:
            linkjs.append(driver.current_url)
            with open(link_path, 'w') as json_file:
                json.dump(linkjs, json_file) 
            rank('925')
            write_comment(f'The result is the {output_type} {result} which not relevant to the query so we can rate the result as Off-Topic  ')

    elif 'lyric' in query_type:
        linkjs.append(driver.current_url)
        with open(link_path, 'w') as json_file:
            json.dump(linkjs, json_file)  
        if disambiguation and output.lower() in disambiguation.lower() and artist.lower() in disambiguation.lower():
            rank('921')
            write_comment(f'The result is the {output_type} {result} which matching that lyrics query so we can rate the result as Perfect ')
        elif query in output.lower():
            rank('924')
            write_comment(f'The result is the {output_type} {result} that poorly satisfies a secondary intent of the query so we can rate the result as Acceptable  ')
        else:
            rank('925')
            write_comment(f'The result is the {output_type} {result} which not relevant to the query so we can rate the result as Off-Topic  ')

    elif 'soundtrack' in query_type:
        linkjs.append(driver.current_url)
        with open(link_path, 'w') as json_file:
            json.dump(linkjs, json_file)  
        query = query.replace('soundtrack','')
        query = query.strip()
        if not disambiguation:
            write_comment(f"The user is looking for {query}'s soundtrack. ")
        if 'artist' in output_type:
            rank('923')
            write_comment(f"The result is the aritst page for {result} of the intended soundtrack so we can rated the result as Good ")
        elif 'song' in output_type:
            if soundtrack():
                rank('922')
                write_comment(f"The result is the {output_type} {result} from the soundtrack compilation so we can rated the result as Exellent")
            elif query in output.lower():
                rank('924')
                write_comment(f"The result is the unpopular {output_type} {result} that matching title of query so we can rate the result as Acceptable")
            else:
                rank('925')
                write_comment(f"The result is the {output_type} {result} which not relevant to the query so we can rate the result as Off-Topic ")
        elif query in output.lower():
            if ('album' in output_type or 'playlist' in output_type ) :
                    if 'original' in output.lower() or 'tv' in output.lower() :
                        if contains_digit(output) and not contains_digit(query):
                            rank('921')
                            write_comment(f"The result is the {output_type} {result} that the user looking for so we can rate the result as Perfect")
                        else:
                            rank('922')
                            write_comment(f"The result is the {output_type} {result} which is version other than the intended one by the query so we can rate the result as Exellent")
                    elif 'theme' in output.lower(): 
                        rank('923')
                        write_comment(f"The result is the {output_type} {result} that would be secondary intent so we can rate the result as Good")
                    else:
                        rank('924')
                        write_comment(f"The result is the unpopular {output_type} {result} that matching title of query so we can rate the result as Acceptable")
            else:
                rank('924')
                write_comment(f"The result is the unpopular {output_type} {result} that matching title of query so we can rate the result as Acceptable")
        else:
            rank('925')
            write_comment(f"The result is the {output_type} {result} which not relevant to the query so we can rate the result as Off-Topic ")

    elif ('play' in query_type or 'album' in query_type) and ('song' in output_type):
        linkjs.append(driver.current_url)
        with open(link_path, 'w') as json_file:
            json.dump(linkjs, json_file)
        if disambiguation:
            if songin(disambiguation):
                rank('922')
                write_comment(f"The result is the {output_type} {result} which from the intend so result can be rated Excellent ")
            elif artist.lower() in query or query in artist.lower():
                rank('923')
                write_comment(f"The result is the {output_type} {result} by the intended artist, therefore can be rated Good. ")

            elif query in output.lower():
                rank('924')
                write_comment(f"The result is the {output_type} {result} which only poorly satisfies the intent but is still relevant and therefore can be rated Acceptable. ")
            else:
                rank('925')
                write_comment(f"The result is the {output_type} {result} which not relevant to the query so we can rate the result as Off-Topic ")
        else:
            if artist.lower() in query or query in artist.lower():
                rank('923')
                write_comment(f"The user is looking for {query}.The result is the {output_type} {result} by the intended artist, therefore can be rated Good. ")

            elif query in output.lower():
                rank('924')
                write_comment(f"The user is looking for {query}. The result is the {output_type} {result} which only poorly satisfies the intent but is still relevant and therefore can be rated Acceptable.")

            else:        
                rank('925')
                write_comment(f"The user is looking for {query}. The result is the {output_type} {result} which not relevant to the query so we can rate the result as Off-Topic .")


    else:
        linkjs.append(driver.current_url)
        with open(link_path, 'w') as json_file:
            json.dump(linkjs, json_file)
        if query in output.lower():
            if disambiguation:
                rank('924')
                write_comment(f"The result is the {output_type} {result} which only poorly satisfies the intent but is still relevant and therefore can be rated Acceptable. ")
            else:
                rank('924')
                write_comment(f"The user is looking for {query}. The result is the {output_type} {result} which only poorly satisfies the intent but is still relevant and therefore can be rated Acceptable.")
        else:
            if disambiguation:
                rank('925')
                write_comment(f"The result is the {output_type} {result} which not relevant to the query so we can rate the result as Off-Topic ")
            else:
                rank('925')
                write_comment(f"The user is looking for {query}. The result is the {output_type} {result} which not relevant to the query so we can rate the result as Off-Topic ")
    if 'unavailable' in output.lower():  
        delete_comment()
        rank('926')
        write_comment(f"The result is Unavailable so we can rate the result as Unacceptable:Other ")
    output = None
    link = None
    query = None
    disambiguation = None
    query_type = None
    output_type = None
    result = None
    true_query = None
    artist = 'RRRRRRRRRR'

# %%
lk =1
dem = 0
kt_run = None 
#b là biến kiểm tra album có phải single không
# if lk == 1:
output = None
chaycode = True
while True:
    try: 
        if 'are currently 0 scrapes with eligible tasks for you' not in driver.find_elements(By.XPATH,"//div[@class='col mb-4']")[2].text:
            driver.find_elements(By.XPATH,"//div[@class='col mb-4']")[2].find_element(By.XPATH,".//button").click()
            while chaycode:
                kt_run = None
                clear_output(wait=True)
                start = time.time()
                print(start)
                print('output hien dang la :',output)
                time.sleep(5)
            
                if 'my task' in driver.find_element(By.XPATH,"//h1").text.lower():
                    print('hết task')
                    driver.get('https://baseline.apple.com/')
                    break
            #         while 'are currently 0 scrapes with eligible tasks' in driver.find_element(By.XPATH,"//td[@colspan='3']").text:
            #             driver.get('https://baseline.apple.com/')
            #             time.sleep(60)
                else:
                    while not kt_run:
                        print('Chưa load được trang')
                        try:
                            input_g = driver.find_element(By.XPATH,"//h1/strong")
                            kt_run = input_g.text
                        except Exception as e:
                            time.sleep(skip)           
                    try:                      

                        if 'top hits'  in driver.find_element(By.XPATH,"//span[@class='crumb']").text.lower(): 
                            try:   
                                delete_comment()
                                output = None
                                link = None
                                query = None
                                disambiguation = None
                                query_type = None
                                output_type = None
                                result = None
                                true_query = None
                                artist = 'RRRRRRRRRR'
                                dataset = data()
                                output = dataset['output']
                                link = dataset['link']
                                query = dataset['query'].lower()
                                disambiguation = dataset['disambiguation']
                                query_type = dataset['query_type']
                                output_type = dataset['output_type'].lower()
                                result = dataset['result']
                                artist = dataset['artist']    
                                true_query = query
                                print(result)
                                
                                op_song,art,intented = intent2(query)
                                op_art, first,viewf = intent3(query)
                                if op_song != 'RRRRRRRRRR' and op_art != 'RRRRRRRRRR':
                                    write_comment(f"The user is looking for {op_song} or {op_art}.")
                                elif op_song != 'RRRRRRRRRR' :
                                    write_comment(f"The user is looking for {op_song}.")
                                elif op_art != 'RRRRRRRRRR' :
                                    write_comment(f"The user is looking for {op_art}.")
                                else:
                                    write_comment(f"The user is looking for {query} query . ")

                                if 'album' in output_type and 'single' in output.lower():
                                    b = single(link,artist)
                                else:
                                    b = None
                                if 'artist' in output_type:
                                    if output.lower() in op_art.lower() or op_art.lower() in output.lower():
                                        rank('2846')
                                        write_comment(f" The result is the intend artist so can rated as Perfect")
                                    elif output.lower() in art.lower() or art.lower() in output.lower():
                                        rank('2847')
                                        write_comment(f" The result is the artist page for {output} who performed the intend song so we can rated as Good")
                                    elif check_startswith(query, output.lower()):
                                        popu,op_art = findart(output)
                                        if 'RRRRRRR' in popu:
                                            rank('2849')
                                            write_comment(f" The result is the unpopular {op_art} which is not related to the prefix so we can rated as Unacceptable: Other")
                                        elif 'un' in popu:
                                            rank('2848')
                                            write_comment(f" The result is the artist page for {op_art} that is relevant to the prefix but unpopular so we can rated as Acceptable")
                                        else:
                                            rank('2847')
                                            write_comment(f" The result is the artist page for {op_art} that likely satisfies a secondary intent of the prefix so we can rated as Good")
                                    else:
                                        rank('2849')
                                        write_comment(f" The result is the unpopular {op_art} which is not related to the prefix so we can rated as Unacceptable: Other")
                                 
                                elif 'song' in output_type:
                                    x = findsong(f'{output} {artist}')
                                    d = driver.find_element(By.XPATH,"//div[@class='col-11 col-lg-5 mx-3']").text
                                    if 'lyric' in d.lower():
                                        if 'RRRRRRR' not in x[0]:
                                            thi = 0
                                            if various():
                                                thi = 1                                    
                                            if 'un' not in x[1]:
                                                if thi ==0:
                                                    rank('2848')
                                                    write_comment(f" The result is popular {x[0]} that poorly related to the query so we can rated as Acceptable")
                                                else:
                                                    rank('2849')
                                                    write_comment(f" The result is popular {x[0]} that poorly related to the query but from third-party compilations so we can rated as Unacceptable: Other")
                                
                                            else:
                                                rank('2849')
                                                write_comment(f" The result is unpopular {x[0]} that poorly related to the query but unpopular so we can rated as Unacceptable: Other")
                            
                                        else:
                                            rank('2849')
                                            write_comment(f" The result is {result} that is not related to the prefix so we can rated as Unacceptable: Other")                               
                                        
                                    else:
                                        if 'RRRRRRR' not in x[0]:
                                            thi = 0
                                            if various():
                                                thi = 1
                                            if (output.lower() in op_song.lower() and artist.lower() in op_song.lower()):
                                                if thi == 0:
                                                    rank('2846')
                                                    write_comment(f" The result is the intend song so can rated as Perfect")
                                                else:
                                                    rank('2847')
                                                    write_comment(f" The result is the intend song from third-party compilations so can rated as Good")
                                            elif (output.lower() in first.lower() and (artist.lower() in op_art.lower() or op_art.lower() in artist.lower() )):
                                                if thi == 0:
                                                    rank('2846')
                                                    write_comment(f" The result is song {first} (+{viewf} streams in Spotify) the most popular of the {op_art} so we can rated as Perfect")
                                                else:
                                                    rank('2847')
                                                    write_comment(f" The result is song {first} (+{viewf} streams in Spotify) the most popular of the {op_art} from third-party compilations so we can rated as Good")
                                            
                                            
                                            elif 'un' not in x[1] and op_art.lower() in x[0]:
                                                if thi ==0:
                                                    rank('2847')
                                                    write_comment(f" The result is popular {x[0]} which is less popular than {first} by {op_art} so we can rated as Good")
                                                else:
                                                    rank('2848')
                                                    write_comment(f" The result is popular {x[0]} which is less popular than {first} by {op_art} from third-party compilations so we can rated as Acceptable")
                                    
                                            elif check_startswith(query, output.lower()):
                                                if 'un' not in x[1]:
                                                    if thi ==0:
                                                        rank('2847')
                                                        write_comment(f" The result is popular {x[0]} that likely satisfies a secondary intent of the prefix so we can rated as Good")
                                                    else:
                                                        rank('2848')
                                                        write_comment(f" The result is popular {x[0]} that likely satisfies a secondary intent of the prefix from third-party compilations so we can rated as Acceptable")
                                    
                                                else:
                                                    if thi ==0:                    
                                                        rank('2848')
                                                        write_comment(f" The result is unpopular {x[0]} that is relevant to the prefix but unpopular so we can rated as Acceptable")
                                                    else:
                                                        rank('2849')
                                                        write_comment(f" The result is unpopular {x[0]} that is relevant to the prefix but unpopular from third-party compilations so we can rated as Unacceptable: Other")
                                    
                                            elif query in output.lower():
                                                if 'un' not in x[1]:
                                                    if thi ==0 :
                                                        
                                                        rank('2848')
                                                        write_comment(f" The result is popular {x[0]} that poorly related to the prefix so we can rated as Acceptable")
                                                    else:
                                                        rank('2849')
                                                        write_comment(f" The result is popular {x[0]} that poorly related to the prefix so we can rated as Unacceptable: Other")
                                    
                                                else:
                                                    rank('2849')
                                                    write_comment(f" The result is unpopular {x[0]} that poorly related to the prefix but unpopular so we can rated as Unacceptable: Other")
                                            else:
                                                rank('2849')
                                                write_comment(f" The result is {result} that is not related to the prefix so we can rated as Unacceptable: Other")
                                        else:
                                            rank('2849')
                                            write_comment(f" The result is {result} that is not related to the prefix so we can rated as Unacceptable: Other")
                                elif b:
                                    ####################################################
                                    x = findsong(b)
                                    if 'RRRRRRR' not in x[0]:
                                        if (output.lower() in op_song.lower() and artist.lower() in op_song.lower()):
                                            rank('2847')
                                            write_comment(f" The result is the album single of intend song so can rated as Good")
                                        elif (b.lower() in first.lower() and (artist.lower() in op_art.lower() or op_art.lower() in artist.lower() )):
                                            rank('2847')
                                            write_comment(f" The result is album single of song {first} (+{viewf} streams in Spotify) the most popular of the {op_art} so we can rated as Good")
                                        elif 'un' not in x[1] and op_art.lower() in x[0]:
                                            rank('2848')
                                            write_comment(f" The result is album single of popular {x[0]} which is less popular than {first} by {op_art} so we can rated as Acceptable")
                                        elif check_startswith(query, output.lower()):
                                            if 'un' not in x[1]:
                                                rank('2848')
                                                write_comment(f" The result is single album of popular {x[0]} that likely satisfies a secondary intent of the prefix so we can rated as Acceptable")
                                            else:                  
                                                rank('2849')
                                                write_comment(f" The result is single album of unpopular {x[0]} that is relevant to the prefix but unpopular so we can rated as Unacceptable: Other")
                              
                                        elif query in output.lower():                                          
                                            rank('2849')
                                            write_comment(f" The result is single album of popular {x[0]} that poorly related to the prefix so we can rated as Unacceptable: Other")
                                        else:
                                            rank('2849')
                                            write_comment(f" The result is {result} that is not related to the prefix so we can rated as Unacceptable: Other")
                                    else:
                                        rank('2849')
                                        write_comment(f" The result is {result} that is not related to the prefix so we can rated as Unacceptable: Other")
                            ############################################################
                                else :
                                    rank("2849")
                                    write_comment(f"The user is looking for {query}. The result is the {output_type} {result} which not relevant to the query so we can rate the result as Unacceptable")
                                    errorjs.append(driver.current_url)
                                    with open(error_path, 'w') as json_file:
                                        json.dump(errorjs, json_file)
                            except:
                                rank("2849")
                                write_comment(f"The result is not relevant to the query so we can rate the result as Unacceptable")
                                errorjs.append(driver.current_url)
                                with open(error_path, 'w') as json_file:
                                    json.dump(errorjs, json_file)
                        else:
                            datajs = {}
                            thread = threading.Thread(target=runcodetranning)
                            # Bắt đầu luồng
                            thread.start()                            
                            # Chờ tối đa 3 phút cho luồng kết thúc
                            thread.join(timeout=240)                            
                            # Kiểm tra xem luồng đã kết thúc chưa
                            if thread.is_alive():
                                # Nếu luồng vẫn đang chạy sau 3 phút, in ra thông báo lỗi
                                print('Lỗi: Quá thời gian tối đa 3 phút')
                                rank('925')
                                write_comment(f"The result doesn't  relevant to the query so we can rate the result as Off-Topic ")
                            else:
                                # Luồng đã kết thúc trong khoảng thời gian cho phép
                                print('Hoàn thành')
                    except Exception as e:
                        print('Lỗi tan bém rồi')
                        errorjs.append(driver.current_url)
                        with open(error_path, 'w') as json_file:
                            json.dump(errorjs, json_file)  
                        try:
                            if query in output.lower():
                                if disambiguation:
                                    rank('924')
                                    write_comment(f"The result is the {output_type} {result} which only poorly satisfies the intent but is still relevant and therefore can be rated Acceptable. ")
                                else:
                                    rank('924')
                                    write_comment(f"The user is looking for {query}. The result is the {output_type} {result} which only poorly satisfies the intent but is still relevant and therefore can be rated Acceptable.")
                            else:
                                if disambiguation:
                                    rank('925')
                                    write_comment(f"The result is the {output_type} {result} which not relevant to the query so we can rate the result as Off-Topic ")
                                else:
                                    rank('925')
                                    write_comment(f"The user is looking for {query}. The result is the {output_type} {result} which not relevant to the query so we can rate the result as Off-Topic ")
                        except Exception as e:
                            rank('925')
                            write_comment(f"The result doesn't  relevant to the query so we can rate the result as Off-Topic ")
                        output = None
                        link = None
                        query = None
                        disambiguation = None
                        query_type = None
                        output_type = None
                        result = None
                        true_query = None
                        artist = 'RRRRRRRRRR'
                    output = None
                    link = None
                    query = None
                    disambiguation = None
                    query_type = None
                    output_type = None
                    result = None
                    true_query = None
                    artist = 'RRRRRRRRRR'   
            
                    print('Done')        
                    end = time.time()
                    run_time = round(end -start)
                    print(run_time,'giây')
                    # try:
                    #     if not driver.find_element(By.XPATH,"//textarea[@id='task_comment']").text:
                    #         linkjs.append(driver.current_url)
                    #         with open(link_path, 'w') as json_file:
                    #             json.dump(linkjs, json_file)
                    # except:
                    #     print("OKOK")
                    if run_time < 54:
                        wait_time = 54 - run_time
                        print(f'sẽ chuyển sau {wait_time} giây')
                        time.sleep(wait_time)
                    print('Bắt đầu chuyển trang')
                    save_next = driver.find_element(By.XPATH,"//input[@name='save_and_next']")
                    save_next.send_keys(Keys.ENTER)
                    print("<><><><><><><><><><><><><><><><><><><><>><><><><><><><><><><")
                    print('chờ 2s load trang')
            ###################################################################################################################
            print('Bấm đi')
            with open(file_path, 'w') as json_file:
                json.dump(datajs, json_file)
            with open(link_path, 'w') as json_file:
                json.dump(linkjs, json_file)    
            with open(error_path, 'w') as json_file:
                json.dump(errorjs, json_file)    
# Bấm ở đây ............................................................
        else:
            dem += 1
            print('--', dem)
            driver.get("https://baseline.apple.com/")
            time.sleep(5)
            time.sleep(5)
            time.sleep(5)
            time.sleep(5)
            time.sleep(5)
            time.sleep(5)
            time.sleep(5)
            time.sleep(5)
            time.sleep(5)            
            time.sleep(5)
            time.sleep(5)
            time.sleep(5)            
            clear_output(wait=True)
            
    except :
        print('Error')
        print('chua co data')
        driver.get("https://baseline.apple.com/")
        time.sleep(5)
        time.sleep(5)
        time.sleep(5)
        time.sleep(5)
        time.sleep(5)
        time.sleep(5)
        time.sleep(5)
        time.sleep(5)
        time.sleep(5)            
        time.sleep(5)
        time.sleep(5)
        time.sleep(5)
        clear_output(wait=True)

#    fernandesalomon387@gmail.com
#    AppleID@160
# Out:
# -- 79

# %%
rank('925')
write_comment(f"The result doesn't  relevant to the query so we can rate the result as Off-Topic ")
save_next = driver.find_element(By.XPATH,"//input[@name='save_and_next']")
save_next.send_keys(Keys.ENTER)

# %%
driver.get('https://baseline.apple.com/')
driver1.get('https://open.spotify.com/')
driver2.get('https://music.apple.com/us/browse')

# %%
a = driver.find_elements(By.XPATH,"//tr")
for b in a:
    if 'Search - Music Top Hits' in b.text:
        after.append(b.find_element(By.XPATH,"./td/a").get_attribute("href"))
print(len(after))
# Out:
# 204

# %%
print(len(after))
# Out:
# 204

# %%
with open(after_path, 'w') as json_file:
    json.dump(after, json_file)

# %%
art = driver1.find_element(By.XPATH,"//section[@data-testid='track-page']//div/span/a").text
print(art)
# Out:
# 1nonly

# %%
for i in fix:
    try:
        del datajs[i]
        print('del',i)
    except:
        j = 0
# Out:
# del post malone last kiss
# del no mercy kms
# del queen new song
# del george ezra green green grass
# del disconnected the kid laroi
# del pgs spence buckle up
# del forever omah
# del cinderella tk music
# del back it up spanian
# del joyner lucas will
# del fedex girl
# del until the end of time coco jones
# del eli brown be the one
# del justin bieber hold on
# del you're losing me taylor swift

# %%
fix = []
for i in datajs:
    a = datajs[i]
    try:
        art_value = a['op_song']
        if 'RRRRRRRRRR' in art_value:
            fix.append(i)
            print(i)
    except:
        print('')
print(len(fix))
# Out:
# disconnected the kid laroi
# 1

# %%
for i in range(0,20,1):
    a = driver.find_elements(By.XPATH,"//tr")
    for b in a:
        if 'Search - Music Top Hits' in b.text:
            after.append(b.find_element(By.XPATH,"./td/a").get_attribute("href"))
    print(len(after))

# %%
linkfix = []
for i in range(1,30,1):
    url = f"https://baseline.apple.com/my_tasks/completed?page={str(i)}"
    driver.get(url)
    time.sleep(5)
    a = driver.find_elements(By.XPATH,"//tr/td")
    i = 2
    j = 0
    k = 0
    for b in a:
        # i = b.find_element(By.XPATH,"./td")
        # print(i)
        if k == 1:    
            linkfix.append(b.find_element(By.XPATH,"./a").get_attribute("href"))   
            k = 0
        if j == i:
            i += 7
            if b.text in fix:
                k = 1
        j+=1
    print(len(linkfix))
linklink = linkfix
# Out:
# 1
# 2
# 4
# 6
# 11
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 13
# 13
# 13
# 13
# 14
# 14
# 14
# 15
# 15
# 15
# 16
# 16
# 17
# 17
# 17

# %%
del datajs['bitter sweet symphony']

# %%
with open(link_path, 'w') as json_file:
    json.dump(linklink, json_file)

# %%
print(len(linkfix))
# Out:
# 0

# %%
d = driver1.find_element(By.XPATH,"//div[@aria-rowindex='1']//a").text
d

# %%
d = driver.find_element(By.XPATH,"//div[@class='col-11 col-lg-5 mx-3']").text
if 'lyric' in d.lower():
    print('11')
# Out:
# 11

# %%
driver.get(after[0])
save_next = driver.find_element(By.XPATH,"//input[@name='commit']")
save_next.send_keys(Keys.ENTER)
after.remove(after[0])

# %%
for i in x:
    if i in after:
        after.remove(i)
print(len(after))
# Out:
# 196

# %%
with open(after_path, 'r') as json_file:
    linkrun = json.load(json_file)
print(len(linkrun))
# Out:
# 155

# %%
linkrun = linklink

# %%
linkrun.remove(linkrun[0])
driver.get(linkrun[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[165], line 2
#       1 linkrun.remove(linkrun[0])
# ----> 2 driver.get(linkrun[0])
#
# IndexError: list index out of range

# %%
a = driver.find_elements(By.XPATH,"//tr")
i = 0
for b in a:
    if 'Search - Music Top Hits' in b.text:
        i+=1
print(i)
# Out:
# 53

# %%
link = 'https://music.apple.com/us/playlist/todays-hits/pl.f4d106fed2bd41149aaacabb233eb5eb'
various()
# Out:
# various
# Today’s Hits
# Đã mở album/ playlist. Ktra xem có tồn tại bài hát không
# False

# %%
a = driver2.find_element(By.XPATH,"//div[@class='headings__subtitles svelte-1ug8xq0']").text
a
# Out:
# 'Apple Music Hits'

# %%
driver1 = webdriver.Chrome()

url = f"https://baseline.apple.com/"
url1 = f"https://chrome.google.com/webstore/detail/nordvpn-vpn-proxy-for-pri/fjoaledfpmneenckfbpdfhkmimnjocfa"
url2 = f"https://chrome.google.com/webstore/detail/proxy-helper/mnloefcpaepkpmhaoipjkpikbnkmbnic"
#mathias.d.kristensen@gmail.com
#Mdkmdkdk99
#45.80.229.85
#:8000:BKott4:5zt7Ck
#fernandesalomon387@gmail.com		AppleID@160
#https://chrome.google.com/webstore/detail/nlipoenfbbikpbjkfpfillcgkoblgpmj
#107.186.189.126:
#64694:eJyLCJqM:GrSHLfUf

driver1.get('https://open.spotify.com/')
